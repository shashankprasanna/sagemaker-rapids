# %% [markdown]
# # Running RAPIDS hyperparameter experiments at scale on Amazon SageMaker

# %% [markdown]
# ##### Import packages and create Amazon SageMaker and Boto3 sessions

# %%
import os
import numpy as np
import time
import numpy as np
import sagemaker
import time
import boto3
from sagemaker.s3 import S3Uploader

sess = boto3.Session()
s3 = boto3.resource('s3')
sagemaker_session = sagemaker.Session()
role = sagemaker.get_execution_role()

# %% [markdown]
# ##### Download the higgs-boson dataset

# %%
# !mkdir dataset
# !wget -P dataset https://archive.ics.uci.edu/ml/machine-learning-databases/00280/HIGGS.csv.gz
# !gunzip dataset/HIGGS.csv.gz

# %% [markdown]
# ##### Download the RAPIDS container from Docker hub

# %%
# !docker pull rapidsai/rapidsai:cuda10.0-runtime-ubuntu16.04
# Out:
# cuda10.0-runtime-ubuntu16.04: Pulling from rapidsai/rapidsai
# Digest: sha256:d83cb5d56e82acba57aae0eef7d2266431b6700ea66e4067e4222cef8bd42162
# Status: Image is up to date for rapidsai/rapidsai:cuda10.0-runtime-ubuntu16.04

# %% [markdown]
# ##### Define hyperparameters: start with best guess values
# Find the full list of Random Forest hyperparameters here in the RAPIDS doc page:
# <br>
# https://rapidsai.github.io/projects/cuml/en/0.11.0/api.html#random-forest

# %%
hyperparams={ 
    'n_estimators'       : 15,
    'max_depth'          : 5,
    'n_bins'             : 8,
    'split_criterion'    : 0,      # GINI:0, ENTROPY:1
    'split_algo'         : 0,      # HIST:0 GLOBAL_QUANTILE:1
    'bootstrap'          : 0,      # true: sample with replacement, false: sample without replacement
    'bootstrap_features' : 0,      # true: sample with replacement, false: sample without replacement
    'max_leaves'         : -1,     # unlimited leaves
    'max_features'       : 0.2, 
}

# %% [markdown]
# ##### Before we run a large scale experiment, test training locally using the SageMaker SDK

# %% [markdown]
# ##### Extend RAPIDS container by copying the training script and installing SageMaker containers which makes RAPIDS compatible with SageMaker

# %%
# !cat docker/Dockerfile
# Out:
# FROM rapidsai/rapidsai:cuda10.0-runtime-ubuntu16.04
#
# RUN apt-get update && apt-get install -y --no-install-recommends build-essential
#
# RUN source activate rapids && pip install sagemaker-containers
#
# # Copies the training code inside the container
# COPY rapids-higgs.py /opt/ml/code/rapids-higgs.py
#
# # Defines rapids-higgs.py as script entry point
# ENV SAGEMAKER_PROGRAM rapids-higgs.py

# %%
# !docker build -t sagemaker-rapids:latest docker
# Out:
# Sending build context to Docker daemon  11.78kB
# Step 1/5 : FROM rapidsai/rapidsai:cuda10.0-runtime-ubuntu16.04
#  ---> 23341e245c4d
# Step 2/5 : RUN apt-get update && apt-get install -y --no-install-recommends build-essential
#  ---> Using cache
#  ---> 5b28bb2de85f
# Step 3/5 : RUN source activate rapids && pip install sagemaker-containers
#  ---> Using cache
#  ---> 6e69dc0b4116
# Step 4/5 : COPY rapids-higgs.py /opt/ml/code/rapids-higgs.py
#  ---> Using cache
#  ---> 798e59534d52
# Step 5/5 : ENV SAGEMAKER_PROGRAM rapids-higgs.py
#  ---> Using cache
#  ---> 7948e55aa3c4
# Successfully built 7948e55aa3c4
# Successfully tagged sagemaker-rapids:latest

# %%
from sagemaker.estimator import Estimator

train_instance_type = 'local_gpu'
local_data_dir = 'file://./dataset'

rapids_estimator = Estimator(image_name='sagemaker-rapids:latest',
                          role=role,
                          train_instance_count=1,
                          train_instance_type=train_instance_type,
                          hyperparameters=hyperparams,
                          metric_definitions=[{'Name': 'test_acc', 'Regex': 'test_acc: ([0-9\\.]+)'}])

# %%
# %%time
rapids_estimator.fit({'dataset': local_data_dir})
# Out:
# Creating tmpksw0arl4_algo-1-ikchj_1 ...
# Attaching to tmpksw0arl4_algo-1-ikchj_12mdone
# algo-1-ikchj_1  | 2020-02-03 23:12:32,332 sagemaker-containers INFO     Invoking user script
# algo-1-ikchj_1  |
# algo-1-ikchj_1  | Training Env:
# algo-1-ikchj_1  |
# algo-1-ikchj_1  | {
# algo-1-ikchj_1  |     "additional_framework_parameters": {},
# algo-1-ikchj_1  |     "channel_input_dirs": {
# algo-1-ikchj_1  |         "dataset": "/opt/ml/input/data/dataset"
# algo-1-ikchj_1  |     },
# algo-1-ikchj_1  |     "current_host": "algo-1-ikchj",
# algo-1-ikchj_1  |     "framework_module": null,
# algo-1-ikchj_1  |     "hosts": [
# algo-1-ikchj_1  |         "algo-1-ikchj"
# algo-1-ikchj_1  |     ],
# algo-1-ikchj_1  |     "hyperparameters": {
# algo-1-ikchj_1  |         "n_estimators": 15,
# algo-1-ikchj_1  |         "max_depth": 5,
# algo-1-ikchj_1  |         "n_bins": 8,
# algo-1-ikchj_1  |         "split_criterion": 0,
# algo-1-ikchj_1  |         "split_algo": 0,
# algo-1-ikchj_1  |         "bootstrap": 0,
# algo-1-ikchj_1  |         "bootstrap_features": 0,
# algo-1-ikchj_1  |         "max_leaves": -1,
# algo-1-ikchj_1  |         "max_features": 0.2
# algo-1-ikchj_1  |     },
# algo-1-ikchj_1  |     "input_config_dir": "/opt/ml/input/config",
# algo-1-ikchj_1  |     "input_data_config": {
# algo-1-ikchj_1  |         "dataset": {
# algo-1-ikchj_1  |             "TrainingInputMode": "File"
# algo-1-ikchj_1  |         }
# algo-1-ikchj_1  |     },
# algo-1-ikchj_1  |     "input_dir": "/opt/ml/input",
# algo-1-ikchj_1  |     "is_master": true,
# algo-1-ikchj_1  |     "job_name": "sagemaker-rapids-2020-02-03-23-12-29-363",
# algo-1-ikchj_1  |     "log_level": 20,
# algo-1-ikchj_1  |     "master_hostname": "algo-1-ikchj",
# algo-1-ikchj_1  |     "model_dir": "/opt/ml/model",
# algo-1-ikchj_1  |     "module_dir": "/opt/ml/code",
# algo-1-ikchj_1  |     "module_name": "rapids-higgs",
# algo-1-ikchj_1  |     "network_interface_name": "eth0",
# algo-1-ikchj_1  |     "num_cpus": 8,
# algo-1-ikchj_1  |     "num_gpus": 1,
# algo-1-ikchj_1  |     "output_data_dir": "/opt/ml/output/data",
# algo-1-ikchj_1  |     "output_dir": "/opt/ml/output",
# algo-1-ikchj_1  |     "output_intermediate_dir": "/opt/ml/output/intermediate",
# algo-1-ikchj_1  |     "resource_config": {
# algo-1-ikchj_1  |         "current_host": "algo-1-ikchj",
# algo-1-ikchj_1  |         "hosts": [
# algo-1-ikchj_1  |             "algo-1-ikchj"
# algo-1-ikchj_1  |         ]
# algo-1-ikchj_1  |     },
# algo-1-ikchj_1  |     "user_entry_point": "rapids-higgs.py"
# algo-1-ikchj_1  | }
# algo-1-ikchj_1  |
# algo-1-ikchj_1  | Environment variables:
# algo-1-ikchj_1  |
# algo-1-ikchj_1  | SM_HOSTS=["algo-1-ikchj"]
# algo-1-ikchj_1  | SM_NETWORK_INTERFACE_NAME=eth0
# algo-1-ikchj_1  | SM_HPS={"bootstrap":0,"bootstrap_features":0,"max_depth":5,"max_features":0.2,"max_leaves":-1,"n_bins":8,"n_estimators":15,"split_algo":0,"split_criterion":0}
# algo-1-ikchj_1  | SM_USER_ENTRY_POINT=rapids-higgs.py
# algo-1-ikchj_1  | SM_FRAMEWORK_PARAMS={}
# algo-1-ikchj_1  | SM_RESOURCE_CONFIG={"current_host":"algo-1-ikchj","hosts":["algo-1-ikchj"]}
# algo-1-ikchj_1  | SM_INPUT_DATA_CONFIG={"dataset":{"TrainingInputMode":"File"}}
# algo-1-ikchj_1  | SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# algo-1-ikchj_1  | SM_CHANNELS=["dataset"]
# algo-1-ikchj_1  | SM_CURRENT_HOST=algo-1-ikchj
# algo-1-ikchj_1  | SM_MODULE_NAME=rapids-higgs
# algo-1-ikchj_1  | SM_LOG_LEVEL=20
# algo-1-ikchj_1  | SM_FRAMEWORK_MODULE=
# algo-1-ikchj_1  | SM_INPUT_DIR=/opt/ml/input
# algo-1-ikchj_1  | SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# algo-1-ikchj_1  | SM_OUTPUT_DIR=/opt/ml/output
# algo-1-ikchj_1  | SM_NUM_CPUS=8
# algo-1-ikchj_1  | SM_NUM_GPUS=1
# algo-1-ikchj_1  | SM_MODEL_DIR=/opt/ml/model
# algo-1-ikchj_1  | SM_MODULE_DIR=/opt/ml/code
# algo-1-ikchj_1  | SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{"dataset":"/opt/ml/input/data/dataset"},"current_host":"algo-1-ikchj","framework_module":null,"hosts":["algo-1-ikchj"],"hyperparameters":{"bootstrap":0,"bootstrap_features":0,"max_depth":5,"max_features":0.2,"max_leaves":-1,"n_bins":8,"n_estimators":15,"split_algo":0,"split_criterion":0},"input_config_dir":"/opt/ml/input/config","input_data_config":{"dataset":{"TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"sagemaker-rapids-2020-02-03-23-12-29-363","log_level":20,"master_hostname":"algo-1-ikchj","model_dir":"/opt/ml/model","module_dir":"/opt/ml/code","module_name":"rapids-higgs","network_interface_name":"eth0","num_cpus":8,"num_gpus":1,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-1-ikchj","hosts":["algo-1-ikchj"]},"user_entry_point":"rapids-higgs.py"}
# algo-1-ikchj_1  | SM_USER_ARGS=["--bootstrap","0","--bootstrap_features","0","--max_depth","5","--max_features","0.2","--max_leaves","-1","--n_bins","8","--n_estimators","15","--split_algo","0","--split_criterion","0"]
# algo-1-ikchj_1  | SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# algo-1-ikchj_1  | SM_CHANNEL_DATASET=/opt/ml/input/data/dataset
# algo-1-ikchj_1  | SM_HP_N_ESTIMATORS=15
# algo-1-ikchj_1  | SM_HP_MAX_DEPTH=5
# algo-1-ikchj_1  | SM_HP_N_BINS=8
# algo-1-ikchj_1  | SM_HP_SPLIT_CRITERION=0
# algo-1-ikchj_1  | SM_HP_SPLIT_ALGO=0
# algo-1-ikchj_1  | SM_HP_BOOTSTRAP=0
# algo-1-ikchj_1  | SM_HP_BOOTSTRAP_FEATURES=0
# algo-1-ikchj_1  | SM_HP_MAX_LEAVES=-1
# algo-1-ikchj_1  | SM_HP_MAX_FEATURES=0.2
# algo-1-ikchj_1  | PYTHONPATH=/opt/ml/code:/opt/conda/envs/rapids/bin:/opt/conda/envs/rapids/lib/python36.zip:/opt/conda/envs/rapids/lib/python3.6:/opt/conda/envs/rapids/lib/python3.6/lib-dynload:/opt/conda/envs/rapids/lib/python3.6/site-packages
# algo-1-ikchj_1  |
# algo-1-ikchj_1  | Invoking script with the following command:
# algo-1-ikchj_1  |
# algo-1-ikchj_1  | /opt/conda/envs/rapids/bin/python rapids-higgs.py --bootstrap 0 --bootstrap_features 0 --max_depth 5 --max_features 0.2 --max_leaves -1 --n_bins 8 --n_estimators 15 --split_algo 0 --split_criterion 0
# algo-1-ikchj_1  |
# algo-1-ikchj_1  |
# algo-1-ikchj_1  | test_acc: 0.6282582944671835
# algo-1-ikchj_1  | 2020-02-03 23:12:46,178 sagemaker-containers INFO     Reporting training SUCCESS
# tmpksw0arl4_algo-1-ikchj_1 exited with code 0
# Aborting on container exit...
# ===== Job Complete =====
# CPU times: user 136 ms, sys: 7.98 ms, total: 144 ms
# Wall time: 17.4 s

# %%
region = boto3.Session().region_name
account = boto3.client('sts').get_caller_identity().get('Account')
image = '{}.dkr.ecr.{}.amazonaws.com/sagemaker-rapids:latest'.format(account, region)

# %%
# !aws ecr create-repository --repository-name sagemaker-rapids
# !$(aws ecr get-login --no-include-email --region {region})
# !docker tag sagemaker-rapids:latest {image}
# !docker push {image}
# Out:
# WARNING! Using --password via the CLI is insecure. Use --password-stdin.
# WARNING! Your password will be stored unencrypted in /home/ec2-user/.docker/config.json.
# Configure a credential helper to remove this warning. See
# https://docs.docker.com/engine/reference/commandline/login/#credentials-store
#
# Login Succeeded
# The push refers to repository [453691756499.dkr.ecr.us-west-2.amazonaws.com/sagemaker-rapids]
#
# b32d3917: Preparing
# 98c6f529: Preparing
# b575b882: Preparing
# 6a090a5a: Preparing
# e3e639c2: Preparing
# 8515050c: Preparing
# b4819abb: Preparing
# 56d33862: Preparing
# cbfdd831: Preparing
# c4e796e4: Preparing
# 80f86be3: Preparing
# 8c8d5f39: Preparing
# 7fbd6c92: Preparing
# 9d138968: Preparing
# a090a5a: Pushing  3.162GB/3.092GBPushing  150.6MB/224.5MBPushing  75.95MB/3.03GBPushing  56.25MB/754.9MBPushing  211.8MB/941.1MBPushing    214MB/941.1MBPushing  269.2MB/3.092GBPushing  267.4MB/268.4MBPushing  642.5MB/941.1MBPushing  33.65MB/122.6MBPushing  486.8MB/3.092GBPushing  512.9MB/3.092GBPushing  890.9MB/941.1MBPushing  743.7MB/3.092GBPushing    752MB/3.092GBPushing  1.042GB/3.03GBPushing  925.6MB/3.092GBPushing  1.317GB/3.03GBPushing  1.023GB/3.092GBPushing  1.429GB/3.03GBPushing  1.431GB/3.03GBPushing  1.113GB/3.092GBPushing  1.457GB/3.03GBPushing  1.398GB/3.092GBPushing  1.431GB/3.092GBPushing  1.555GB/3.092GBPushing  2.115GB/3.03GBPushing  2.119GB/3.03GBPushing  2.185GB/3.03GBPushing  1.886GB/3.092GBPushing  2.067GB/3.092GBPushing  2.501GB/3.03GBPushing  2.522GB/3.03GBPushing  2.193GB/3.092GBPushing  2.371GB/3.092GBPushing  2.554GB/3.092GBPushing  2.612GB/3.092GBPushing  2.613GB/3.092GBPushing  2.816GB/3.092GBPushing   3.01GB/3.092GBPushing  3.147GBPushed latest: digest: sha256:e03f2564410d599e5868bb97cf7b0999860adf4976037ccc23dd40a84a523993 size: 3478

# %%
from sagemaker.tuner import IntegerParameter, CategoricalParameter, ContinuousParameter, HyperparameterTuner

hyperparameter_ranges = {
    'n_estimators'        : IntegerParameter(10, 200), 
    'max_depth'           : IntegerParameter(1, 22),
    'n_bins'              : IntegerParameter(5, 24),
    'split_criterion'     : CategoricalParameter([0, 1]),
    'split_algo'          : CategoricalParameter([0, 1]),
    'bootstrap'           : CategoricalParameter([True, False]),
    'bootstrap_features'  : CategoricalParameter([True, False]),
    'max_features'        : ContinuousParameter(0.01, 0.5),
}

# %%
from sagemaker.estimator import Estimator

train_instance_type = 'ml.p3.2xlarge'
rapids_estimator = Estimator(image_name=image,
                          role=role,
                          train_instance_count=1,
                          train_instance_type=train_instance_type,
                          hyperparameters=hyperparams,
                          metric_definitions=[{'Name': 'test_acc', 'Regex': 'test_acc: ([0-9\\.]+)'}])

# %%
tuner = HyperparameterTuner(rapids_estimator,
                            objective_metric_name='test_acc',
                            hyperparameter_ranges=hyperparameter_ranges,
                            strategy='Bayesian',
                            max_jobs=1,
                            max_parallel_jobs=1,
                            objective_type='Maximize',
                            metric_definitions=[{'Name': 'test_acc', 'Regex': 'test_acc: ([0-9\\.]+)'}])

# %% [markdown]
# ##### Upload it to the default SageMaker bucket on Amazon S3

# %%
s3_data_dir = sagemaker_session.upload_data(path='dataset', key_prefix='dataset/higgs-dataset')

# %%
job_name = 'rapidsHPO' + time.strftime('%Y-%m-%d-%H-%M-%S-%j', time.gmtime())
tuner.fit({'dataset': s3_data_dir}, job_name=job_name)

# %% [markdown]
# ## Clean up

# %% [markdown]
# - Delete S3 buckets and files you don't need
# - Kill training jobs that you don't want running
# - Delete container images and the repository you just created

# %%
aws ecr delete-repository --force --repository-name
